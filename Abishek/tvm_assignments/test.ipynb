# %%
import tvm
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import tvm
#
# File f:\tvm\tvm\python\tvm\__init__.py:26
#      22 import traceback
#      24 # top-level alias
#      25 # tvm._ffi
# ---> 26 from ._ffi.base import TVMError, __version__, _RUNTIME_ONLY
#      28 from ._ffi.runtime_ctypes import DataTypeCode, DataType
#      29 from ._ffi import register_object, register_func, register_extension, get_global_func
#
# File f:\tvm\tvm\python\tvm\_ffi\__init__.py:28
#      17 """C interfacing code.
#      18
#      19 This namespace contains everything that interacts with C code.
#    (...)
#      25 and have a ctypes fallback implementation.
#      26 """
#      27 from . import _pyversion
# ---> 28 from .base import register_error
#      29 from .registry import register_object, register_func, register_extension
# ...
